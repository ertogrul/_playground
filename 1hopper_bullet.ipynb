# %% [markdown]
# # IBM Think 2020 Code Cafe - Tic Tac Toe with DeepMind OpenSpiel
#
# ![https://nextgrid.ai/wp-content/uploads/2020/05/ibmthink.png](https://nextgrid.ai/wp-content/uploads/2020/05/ibmthink.png)
#
#
# # PyBullet hopper with stable-baselines

# %% [markdown]
# In this notebook, you will use a stable-baselines RL algorithm to train a one leg robot to move forward.
# The goal is to move forward as fast as possible and don't fall.
# The task considered to be solved when your robot consistently achieves score 3000.

# %% [markdown]
# ## Hopper:
# Your robot will solve [Hopper](https://gym.openai.com/envs/Hopper-v2/) environment.
# We will use implementation in [PyBullet gym](https://github.com/benelot/pybullet-gym).
#
# The reward signal that used to train your model is the following:
# * The agent gets a positive reward for distance walked forward, a successful agent can get 3000+ till the end of the episode.
# * If walker fall episode ends.

# %% [markdown]
# ## Instructions

# %% [markdown]
# Open this notebook on your machine and run all cells one by one.

# %% [markdown]
# ## Tensorboard

# %% [markdown]
# Here we set the path for tensorboard logs.
# [Tensorboard](https://www.tensorflow.org/tensorboard) is a tool for visualization of machine learning experiments

# %%
tensorboard_dir = "tensorboard"

# %% [markdown]
# On this machine you can open tensorboard on following adress https://hub.nextgrid.ai/proxy/6006.

# %% [markdown]
# ## Training

# %% [markdown]
# First, we import all stuff that will be needed

# %%
# Create virtual display to render on remote machine
from pyvirtualdisplay import Display
display = Display(visible=0, size=(1, 1))
display.start()

import gym
import pybulletgym

from stable_baselines.common.vec_env import DummyVecEnv
from stable_baselines.common.evaluation import evaluate_policy

from notebooks.utils import record_and_show
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-203c4b5d0c6f> in <module>
#       1 # Create virtual display to render on remote machine
# ----> 2 from pyvirtualdisplay import Display
#       3 display = Display(visible=0, size=(1, 1))
#       4 display.start()
#       5
#
# ModuleNotFoundError: No module named 'pyvirtualdisplay'

# %% [markdown]
# In this example we will use **Soft Actor-Critic algorithm (SAC)**:  \
# **Full list** of algorithms available with stable-baselines: https://stable-baselines.readthedocs.io/en/master/guide/algos.html
# You can read more about SAC in **stable-baselines documentation:** https://stable-baselines.readthedocs.io/en/master/modules/sac.html

# %%
from stable_baselines import SAC
from stable_baselines.sac.policies import MlpPolicy

# %% [markdown]
# ### Initialize environment
#
# Before we start training we need to create an instance of the environment for our model.

# %%
env_name = 'HopperPyBulletEnv-v0'
environment = DummyVecEnv([lambda: gym.make(env_name)])
# Out:
# WalkerBase::__init__
# /home/jupyter/venv37/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %% [markdown]
# ### Initialize model
#
# Now we are creating an instance of the model.
# Note that this is a step where you can later change the parameters of the algorithm.
# Parameters that we used are from [stablebaselines-zoo](https://github.com/araffin/rl-baselines-zoo/blob/master/hyperparams/sac.yml) where you can find it also for other models and environemnts.

# %%
model = SAC(
    MlpPolicy, 
    environment,
    buffer_size=int(1e6),
    batch_size=256,
    learning_starts=1000,
    verbose=1,
    tensorboard_log=tensorboard_dir,
)
# Out:
# WARNING:tensorflow:From /home/jupyter/venv37/lib/python3.7/site-packages/stable_baselines/common/tf_util.py:191: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /home/jupyter/venv37/lib/python3.7/site-packages/stable_baselines/common/tf_util.py:200: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /home/jupyter/venv37/lib/python3.7/site-packages/stable_baselines/sac/sac.py:142: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /home/jupyter/venv37/lib/python3.7/site-packages/stable_baselines/common/input.py:25: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /home/jupyter/venv37/lib/python3.7/site-packages/stable_baselines/sac/policies.py:194: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From /home/jupyter/venv37/lib/python3.7/site-packages/tensorflow_core/python/layers/core.py:332: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /home/jupyter/venv37/lib/python3.7/site-packages/stable_baselines/common/tf_layers.py:57: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.Dense instead.
# WARNING:tensorflow:From /home/jupyter/venv37/lib/python3.7/site-packages/stable_baselines/sac/policies.py:216: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# WARNING:tensorflow:From /home/jupyter/venv37/lib/python3.7/site-packages/stable_baselines/sac/policies.py:63: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /home/jupyter/venv37/lib/python3.7/site-packages/stable_baselines/sac/sac.py:197: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /home/jupyter/venv37/lib/python3.7/site-packages/stable_baselines/sac/sac.py:233: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /home/jupyter/venv37/lib/python3.7/site-packages/stable_baselines/common/tf_util.py:449: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From /home/jupyter/venv37/lib/python3.7/site-packages/stable_baselines/common/tf_util.py:449: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /home/jupyter/venv37/lib/python3.7/site-packages/tensorflow_core/python/ops/math_grad.py:1375: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /home/jupyter/venv37/lib/python3.7/site-packages/stable_baselines/sac/sac.py:269: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /home/jupyter/venv37/lib/python3.7/site-packages/stable_baselines/sac/sac.py:296: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From /home/jupyter/venv37/lib/python3.7/site-packages/stable_baselines/sac/sac.py:313: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# WARNING:tensorflow:From /home/jupyter/venv37/lib/python3.7/site-packages/stable_baselines/sac/sac.py:316: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.

# %% [markdown]
# ### Record video

# %% [markdown]
# This function we use to record the behavior of our model in the environment.
# First, it records an episode and save it into the `videos` folder, then open it in the notebook cell.

# %%
record_and_show(env_name, model, name="hopper_random")
# Out:
# WalkerBase::__init__
# /home/jupyter/venv37/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# Saving video to  /home/jupyter/notebooks/videos/hopper_random-step-0-to-step-500.mp4
# <video alt="videos/hopper_random-step-0-to-step-500.mp4" autoplay
#                     loop controls style="height: 400px;">
#                     <source src="data:video/mp4;base64,..." type="video/mp4" />
#                 </video>

# %% [markdown]
# ### Calculate score

# %% [markdown]
# The function below is a standard stable-baselines function for **model evaluation**. \
# The most important argument that you should track is `n_eval_episodes`, \
# that defines how many episodes you want to evaluate your model.

# %%
# %%time
eval_env = DummyVecEnv([lambda: gym.make(env_name)])
new_evaluation = evaluate_policy(model, eval_env, n_eval_episodes=10, deterministic=True)
print("Mean reward is", new_evaluation[0])
# Out:
# WalkerBase::__init__
# Mean reward is 25.931894
# CPU times: user 185 ms, sys: 28.2 ms, total: 213 ms
# Wall time: 186 ms
# /home/jupyter/venv37/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %% [markdown]
# ### Train

# %% [markdown]
# Train our model. Note that we use **magic command ```%%time```** to track time for this cell.

# %%
# %%time
model.learn(total_timesteps=20000, log_interval=100)
# Out:
# WARNING:tensorflow:From /home/jupyter/venv37/lib/python3.7/site-packages/stable_baselines/common/base_class.py:1143: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# WARNING:tensorflow:From /home/jupyter/venv37/lib/python3.7/site-packages/stable_baselines/common/tf_util.py:502: The name tf.Summary is deprecated. Please use tf.compat.v1.Summary instead.
#
# ----------------------------------------
# | current_lr              | 0.0003     |
# | ent_coef                | 0.9505118  |
# | ent_coef_loss           | -0.2534377 |
# | entropy                 | 3.850677   |
# | episodes                | 100        |
# | fps                     | 360        |
# | mean 100 episode reward | 20.3       |
# | n_updates               | 169        |
# | policy_loss             | -4.9298334 |
# | qf1_loss                | 0.87219423 |
# | qf2_loss                | 0.785406   |
# | time_elapsed            | 3          |
# | total timesteps         | 1168       |
# | value_loss              | 0.29586118 |
# ----------------------------------------
# ----------------------------------------
# | current_lr              | 0.0003     |
# | ent_coef                | 0.77941763 |
# | ent_coef_loss           | -1.121196  |
# | entropy                 | 3.478249   |
# | episodes                | 200        |
# | fps                     | 192        |
# | mean 100 episode reward | 17.8       |
# | n_updates               | 852        |
# | policy_loss             | -13.289031 |
# | qf1_loss                | 0.5632518  |
# | qf2_loss                | 0.58710605 |
# | time_elapsed            | 9          |
# | total timesteps         | 1851       |
# | value_loss              | 0.44125935 |
# ----------------------------------------
# ----------------------------------------
# | current_lr              | 0.0003     |
# | ent_coef                | 0.55085754 |
# | ent_coef_loss           | -2.7558746 |
# | entropy                 | 3.2797132  |
# | episodes                | 300        |
# | fps                     | 147        |
# | mean 100 episode reward | 19.6       |
# | n_updates               | 2011       |
# | policy_loss             | -18.062447 |
# | qf1_loss                | 0.28005344 |
# | qf2_loss                | 0.3087709  |
# | time_elapsed            | 20         |
# | total timesteps         | 3010       |
# | value_loss              | 0.2542066  |
# ----------------------------------------
# ----------------------------------------
# | current_lr              | 0.0003     |
# | ent_coef                | 0.13807727 |
# | ent_coef_loss           | -5.071743  |
# | entropy                 | 1.6016176  |
# | episodes                | 400        |
# | fps                     | 119        |
# | mean 100 episode reward | 49.7       |
# | n_updates               | 7136       |
# | policy_loss             | -30.279446 |
# | qf1_loss                | 0.9550712  |
# | qf2_loss                | 0.88229895 |
# | time_elapsed            | 68         |
# | total timesteps         | 8135       |
# | value_loss              | 0.25799298 |
# ----------------------------------------
# CPU times: user 5min 4s, sys: 21.3 s, total: 5min 25s
# Wall time: 3min 1s

# %% [markdown]
# After the run we can record video and see how our agent behaves in the simulation:

# %%
record_and_show(env_name, model, name="hopper_20k")
# Out:
# WalkerBase::__init__
# /home/jupyter/venv37/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# Saving video to  /home/jupyter/notebooks/videos/hopper_20k-step-0-to-step-500.mp4
# <video alt="videos/hopper_20k-step-0-to-step-500.mp4" autoplay
#                     loop controls style="height: 400px;">
#                     <source src="data:video/mp4;base64,..." type="video/mp4" />
#                 </video>

# %% [markdown]
# At this moment your hopper should learn to not to fall or even jump .

# %%
# %%time
eval_env = DummyVecEnv([lambda: gym.make(env_name)])
new_evaluation = evaluate_policy(model, eval_env, n_eval_episodes=10, deterministic=True)
print("Mean reward is", new_evaluation[0])
# Out:
# WalkerBase::__init__
# /home/jupyter/venv37/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# Mean reward is 908.9998
# CPU times: user 14.6 s, sys: 561 ms, total: 15.2 s
# Wall time: 13.3 s

# %% [markdown]
# As you can see reward is becoming higher.
# So, let's train it a little longer (execution of this cell should take some time to finish):

# %%
# %%time
model.learn(total_timesteps=80000, log_interval=50)
# Out:
# --------------------------------------
# | current_lr              | 0.0003   |
# | episodes                | 50       |
# | fps                     | 867      |
# | mean 100 episode reward | 20.3     |
# | n_updates               | 0        |
# | time_elapsed            | 0        |
# | total timesteps         | 594      |
# --------------------------------------
# -----------------------------------------
# | current_lr              | 0.0003      |
# | ent_coef                | 0.021427257 |
# | ent_coef_loss           | 0.030131638 |
# | entropy                 | -1.2737393  |
# | episodes                | 100         |
# | fps                     | 107         |
# | mean 100 episode reward | 149         |
# | n_updates               | 15002       |
# | policy_loss             | -61.292416  |
# | qf1_loss                | 0.3338942   |
# | qf2_loss                | 0.60347223  |
# | time_elapsed            | 149         |
# | total timesteps         | 16001       |
# | value_loss              | 0.14256272  |
# -----------------------------------------
# ------------------------------------------
# | current_lr              | 0.0003       |
# | ent_coef                | 0.0147185875 |
# | ent_coef_loss           | 2.1377733    |
# | entropy                 | -1.3203652   |
# | episodes                | 150          |
# | fps                     | 104          |
# | mean 100 episode reward | 557          |
# | n_updates               | 64167        |
# | policy_loss             | -68.638214   |
# | qf1_loss                | 0.32050613   |
# | qf2_loss                | 0.4435274    |
# | time_elapsed            | 621          |
# | total timesteps         | 65166        |
# | value_loss              | 0.18182099   |
# ------------------------------------------
# CPU times: user 21min 14s, sys: 1min 31s, total: 22min 46s
# Wall time: 12min 43s

# %% [markdown]
# Let's take a look what we got:

# %%
record_and_show(env_name, model, name="hopper_100k")
# Out:
# WalkerBase::__init__
# /home/jupyter/venv37/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# Saving video to  /home/jupyter/notebooks/videos/hopper_100k-step-0-to-step-500.mp4
# <video alt="videos/hopper_100k-step-0-to-step-500.mp4" autoplay
#                     loop controls style="height: 400px;">
#                     <source src="data:video/mp4;base64,..." type="video/mp4" />
#                 </video>

# %%
# %%time
eval_env = DummyVecEnv([lambda: gym.make(env_name)])
new_evaluation = evaluate_policy(model, eval_env, n_eval_episodes=10, deterministic=True)
print("Mean reward is", new_evaluation[0])
# Out:
# WalkerBase::__init__
# /home/jupyter/venv37/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# Mean reward is 903.7381
# CPU times: user 14.4 s, sys: 603 ms, total: 15 s
# Wall time: 13.1 s

# %% [markdown]
# The results will not be very exciting, however, the agent should make some progress.
# Now, let's run it for 400k steps and see how well our model could learn. \
# If you have tensorboard running at the beginning of the notebook, you can monitor the training process there.
# (**Warning**: this cell could take some time to execute due to high number of steps and updates)

# %%
# %%time
model.learn(total_timesteps=400000, log_interval=30)
# Out:
# --------------------------------------
# | current_lr              | 0.0003   |
# | episodes                | 30       |
# | fps                     | 825      |
# | mean 100 episode reward | 19.7     |
# | n_updates               | 0        |
# | time_elapsed            | 0        |
# | total timesteps         | 333      |
# --------------------------------------
# --------------------------------------
# | current_lr              | 0.0003   |
# | episodes                | 60       |
# | fps                     | 838      |
# | mean 100 episode reward | 19.9     |
# | n_updates               | 0        |
# | time_elapsed            | 0        |
# | total timesteps         | 642      |
# --------------------------------------
# --------------------------------------
# | current_lr              | 0.0003   |
# | episodes                | 90       |
# | fps                     | 835      |
# | mean 100 episode reward | 19.7     |
# | n_updates               | 0        |
# | time_elapsed            | 1        |
# | total timesteps         | 949      |
# --------------------------------------
# -----------------------------------------
# | current_lr              | 0.0003      |
# | ent_coef                | 0.02925402  |
# | ent_coef_loss           | 0.29245365  |
# | entropy                 | -0.5415967  |
# | episodes                | 120         |
# | fps                     | 109         |
# | mean 100 episode reward | 220         |
# | n_updates               | 24203       |
# | policy_loss             | -69.18491   |
# | qf1_loss                | 0.119762644 |
# | qf2_loss                | 0.19349551  |
# | time_elapsed            | 230         |
# | total timesteps         | 25202       |
# | value_loss              | 0.04501137  |
# -----------------------------------------
# -----------------------------------------
# | current_lr              | 0.0003      |
# | ent_coef                | 0.020027937 |
# | ent_coef_loss           | -0.7067312  |
# | entropy                 | -1.1481004  |
# | episodes                | 150         |
# | fps                     | 107         |
# | mean 100 episode reward | 444         |
# | n_updates               | 48935       |
# | policy_loss             | -70.84055   |
# | qf1_loss                | 9.995408    |
# | qf2_loss                | 9.929054    |
# | time_elapsed            | 463         |
# | total timesteps         | 49934       |
# | value_loss              | 0.11849225  |
# -----------------------------------------
# -----------------------------------------
# | current_lr              | 0.0003      |
# | ent_coef                | 0.019267656 |
# | ent_coef_loss           | -0.17128517 |
# | entropy                 | -1.5874894  |
# | episodes                | 180         |
# | fps                     | 106         |
# | mean 100 episode reward | 703         |
# | n_updates               | 75804       |
# | policy_loss             | -75.04758   |
# | qf1_loss                | 0.12069206  |
# | qf2_loss                | 0.41008347  |
# | time_elapsed            | 720         |
# | total timesteps         | 76803       |
# | value_loss              | 0.26096642  |
# -----------------------------------------
# -----------------------------------------
# | current_lr              | 0.0003      |
# | ent_coef                | 0.016487008 |
# | ent_coef_loss           | 0.1589184   |
# | entropy                 | -1.6239338  |
# | episodes                | 210         |
# | fps                     | 106         |
# | mean 100 episode reward | 855         |
# | n_updates               | 105692      |
# | policy_loss             | -75.11245   |
# | qf1_loss                | 0.2852741   |
# | qf2_loss                | 0.4351899   |
# | time_elapsed            | 1003        |
# | total timesteps         | 106691      |
# | value_loss              | 0.1713861   |
# -----------------------------------------
# -----------------------------------------
# | current_lr              | 0.0003      |
# | ent_coef                | 0.02452484  |
# | ent_coef_loss           | -0.1775926  |
# | entropy                 | -0.40586522 |
# | episodes                | 240         |
# | fps                     | 106         |
# | mean 100 episode reward | 925         |
# | n_updates               | 133852      |
# | policy_loss             | -75.645355  |
# | qf1_loss                | 0.14314364  |
# | qf2_loss                | 0.1335019   |
# | time_elapsed            | 1268        |
# | total timesteps         | 134851      |
# | value_loss              | 0.11392973  |
# -----------------------------------------
# -----------------------------------------
# | current_lr              | 0.0003      |
# | ent_coef                | 0.029846022 |
# | ent_coef_loss           | -0.5864563  |
# | entropy                 | -0.5058439  |
# | episodes                | 270         |
# | fps                     | 105         |
# | mean 100 episode reward | 956         |
# | n_updates               | 163852      |
# | policy_loss             | -76.25107   |
# | qf1_loss                | 0.29179466  |
# | qf2_loss                | 0.62536263  |
# | time_elapsed            | 1557        |
# | total timesteps         | 164851      |
# | value_loss              | 0.09853329  |
# -----------------------------------------
# -----------------------------------------
# | current_lr              | 0.0003      |
# | ent_coef                | 0.025162375 |
# | ent_coef_loss           | -0.5448683  |
# | entropy                 | -0.4442896  |
# | episodes                | 300         |
# | fps                     | 105         |
# | mean 100 episode reward | 957         |
# | n_updates               | 193852      |
# | policy_loss             | -76.55071   |
# | qf1_loss                | 0.09514536  |
# | qf2_loss                | 0.07970376  |
# | time_elapsed            | 1840        |
# | total timesteps         | 194851      |
# | value_loss              | 0.10447146  |
# -----------------------------------------
# -----------------------------------------
# | current_lr              | 0.0003      |
# | ent_coef                | 0.024501484 |
# | ent_coef_loss           | 0.51791644  |
# | entropy                 | -0.7309484  |
# | episodes                | 330         |
# | fps                     | 105         |
# | mean 100 episode reward | 1e+03       |
# | n_updates               | 223676      |
# | policy_loss             | -77.32202   |
# | qf1_loss                | 0.1790175   |
# | qf2_loss                | 0.16095667  |
# | time_elapsed            | 2120        |
# | total timesteps         | 224675      |
# | value_loss              | 0.22479168  |
# -----------------------------------------
# -----------------------------------------
# | current_lr              | 0.0003      |
# | ent_coef                | 0.022764696 |
# | ent_coef_loss           | -0.21216176 |
# | entropy                 | -0.86260283 |
# | episodes                | 360         |
# | fps                     | 106         |
# | mean 100 episode reward | 1.01e+03    |
# | n_updates               | 252474      |
# | policy_loss             | -80.36222   |
# | qf1_loss                | 13.371508   |
# | qf2_loss                | 13.343306   |
# | time_elapsed            | 2389        |
# | total timesteps         | 253473      |
# | value_loss              | 0.053671278 |
# -----------------------------------------
# -----------------------------------------
# | current_lr              | 0.0003      |
# | ent_coef                | 0.022987789 |
# | ent_coef_loss           | 0.83269686  |
# | entropy                 | -0.745718   |
# | episodes                | 390         |
# | fps                     | 106         |
# | mean 100 episode reward | 1.00e+03    |
# | n_updates               | 282474      |
# | policy_loss             | -79.91051   |
# | qf1_loss                | 0.18860817  |
# | qf2_loss                | 0.1177293   |
# | time_elapsed            | 2667        |
# | total timesteps         | 283473      |
# | value_loss              | 0.0855598   |
# -----------------------------------------
# -----------------------------------------
# | current_lr              | 0.0003      |
# | ent_coef                | 0.025560154 |
# | ent_coef_loss           | 0.042735495 |
# | entropy                 | -0.49388582 |
# | episodes                | 420         |
# | fps                     | 106         |
# | mean 100 episode reward | 990         |
# | n_updates               | 311631      |
# | policy_loss             | -80.84538   |
# | qf1_loss                | 0.1647452   |
# | qf2_loss                | 0.18860367  |
# | time_elapsed            | 2935        |
# | total timesteps         | 312630      |
# | value_loss              | 0.05036535  |
# -----------------------------------------
# -----------------------------------------
# | current_lr              | 0.0003      |
# | ent_coef                | 0.026799984 |
# | ent_coef_loss           | 0.048370548 |
# | entropy                 | -0.31820613 |
# | episodes                | 450         |
# | fps                     | 106         |
# | mean 100 episode reward | 910         |
# | n_updates               | 335095      |
# | policy_loss             | -82.20421   |
# | qf1_loss                | 0.13289459  |
# | qf2_loss                | 0.20997949  |
# | time_elapsed            | 3153        |
# | total timesteps         | 336094      |
# | value_loss              | 0.5173977   |
# -----------------------------------------
# -----------------------------------------
# | current_lr              | 0.0003      |
# | ent_coef                | 0.026457913 |
# | ent_coef_loss           | 0.78632814  |
# | entropy                 | -0.47838664 |
# | episodes                | 480         |
# | fps                     | 106         |
# | mean 100 episode reward | 874         |
# | n_updates               | 355963      |
# | policy_loss             | -82.613205  |
# | qf1_loss                | 0.20921263  |
# | qf2_loss                | 0.24592808  |
# | time_elapsed            | 3344        |
# | total timesteps         | 356962      |
# | value_loss              | 0.2569725   |
# -----------------------------------------
# -----------------------------------------
# | current_lr              | 0.0003      |
# | ent_coef                | 0.029886859 |
# | ent_coef_loss           | -0.8807415  |
# | entropy                 | 0.14626233  |
# | episodes                | 510         |
# | fps                     | 106         |
# | mean 100 episode reward | 767         |
# | n_updates               | 369594      |
# | policy_loss             | -84.73554   |
# | qf1_loss                | 0.22521487  |
# | qf2_loss                | 0.2305235   |
# | time_elapsed            | 3469        |
# | total timesteps         | 370593      |
# | value_loss              | 0.064509474 |
# -----------------------------------------
# -----------------------------------------
# | current_lr              | 0.0003      |
# | ent_coef                | 0.027037123 |
# | ent_coef_loss           | 1.4114127   |
# | entropy                 | -0.40907508 |
# | episodes                | 540         |
# | fps                     | 106         |
# | mean 100 episode reward | 676         |
# | n_updates               | 384836      |
# | policy_loss             | -88.028076  |
# | qf1_loss                | 13.501798   |
# | qf2_loss                | 13.482335   |
# | time_elapsed            | 3608        |
# | total timesteps         | 385835      |
# | value_loss              | 0.26996878  |
# -----------------------------------------
# CPU times: user 1h 45min 12s, sys: 7min 38s, total: 1h 52min 50s
# Wall time: 1h 2min 20s

# %% [markdown]
# Now let's see what our model learned after performing 500k steps in the simulation:

# %%
record_and_show(env_name, model, name="hopper_500k")
# Out:
# WalkerBase::__init__
# /home/jupyter/venv37/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# Saving video to  /home/jupyter/notebooks/videos/hopper_500k-step-0-to-step-500.mp4
# <video alt="videos/hopper_500k-step-0-to-step-500.mp4" autoplay
#                     loop controls style="height: 400px;">
#                     <source src="data:video/mp4;base64,..." type="video/mp4" />
#                 </video>

# %% [markdown]
# We also can check the score:

# %%
# %%time
eval_env = DummyVecEnv([lambda: gym.make(env_name)])
new_evaluation = evaluate_policy(model, eval_env, n_eval_episodes=25, deterministic=True)
print("Mean reward is", new_evaluation[0])
# Out:
# WalkerBase::__init__
# /home/jupyter/venv37/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# Mean reward is 950.9963
# CPU times: user 34.9 s, sys: 1.46 s, total: 36.3 s
# Wall time: 31.7 s

# %% [markdown]
# At this moment you should expect that the agent will start to move forward.
# However, the score will not be perfect, and model requires futher training.

# %% [markdown]
# ### Saving the model

# %% [markdown]
# If you are happy with this model you can save it to a file and load later:

# %%
model.save("hopper_sac_500k")

# %% [markdown]
# So, at this moment we expected to have successfully trained policy that can steer hopper.
# But it unlikely to be perfect and you'd need to train it more :) \
# Here are some advises what you can try next:
# 1. Continue the training and see how agent improves.
# 2. Train this algorithm in another [environment](https://gym.openai.com/) (start with simple ones like `CartPole` or `LunarLander`) to do that you need to change env_name at 5-th cell.
# 3. Train agent with another algorithm (different algorithms perform best on different problems)
